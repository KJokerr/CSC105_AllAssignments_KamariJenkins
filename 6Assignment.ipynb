# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("data/job_postings.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15886 entries, 0 to 15885
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   job_id                      15886 non-null  int64
#  1   company_id                  15520 non-null  float64
#  2   title                       15886 non-null  object
#  3   description                 15885 non-null  object
#  4   max_salary                  5521 non-null   float64
#  5   med_salary                  981 non-null    float64
#  6   min_salary                  5521 non-null   float64
#  7   pay_period                  6502 non-null   object
#  8   formatted_work_type         15886 non-null  object
#  9   location                    15886 non-null  object
#  10  applies                     8700 non-null   float64
#  11  original_listed_time        15886 non-null  int64
#  12  remote_allowed              2340 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['job_id', 'company_id', 'title', 'description', 'max_salary',
#        'med_salary', 'min_salary', 'pay_period', 'formatted_work_type',
#        'location', 'applies', 'original_listed_time', 'remote_allowed',
#        'views', 'job_posting_url', 'application_url', 'application_type',
#        'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc',
#        'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency',
#        'compensation_type'],
#       dtype='object')

# %%
df.head()
# Out:
#       job_id  company_id                     title  \
# 0   85008768         NaN  Licensed Insurance Agent
# 1  133114754  77766802.0             Sales Manager
# 2  133196985   1089558.0        Model Risk Auditor
# 3  381055942  96654609.0          Business Manager
# 4  529257371   1244539.0       NY Studio Assistant
#
#                                          description  max_salary  med_salary  \
# 0  While many industries were hurt by the last fe...     52000.0         NaN
# 1  Are you a dynamic and creative marketing profe...         NaN         NaN
# 2  Join Us as a Model Risk Auditor – Showcase You...         NaN         NaN
# 3  Business ManagerFirst Baptist Church ForneyFor...         NaN         NaN
# 4  YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN         NaN
#
#    min_salary pay_period formatted_work_type           location  ...  \
# 0     45760.0     YEARLY           Full-time          Chico, CA  ...
# ...

# %%
Job_Title = df["title"]

# %%
Minimum_Salary = df["min_salary"]

# %%
Job_Location = df["location"]

# %%
Job_Location = df["location"]

# %%
df[["title", "min_salary", "location"]]
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %%
df2 = df[["title", "min_salary", "location"]]

# %%
df2
# Out:
#                                        title  min_salary           location
# 0                   Licensed Insurance Agent     45760.0          Chico, CA
# 1                              Sales Manager         NaN  Santa Clarita, CA
# 2                         Model Risk Auditor         NaN       New York, NY
# 3                           Business Manager         NaN         Forney, TX
# 4                        NY Studio Assistant         NaN       New York, NY
# ...                                      ...         ...                ...
# 15881                  Sanitation Technician         NaN  West Columbia, SC
# 15882                         Unit Secretary         NaN        Teaneck, NJ
# 15883                Radiology Aide, Perdiem         NaN        Teaneck, NJ
# 15884                            MRI Manager    110000.0       New York, NY
# 15885  Area Director of Business Development         NaN      Vicksburg, MS
#
# [15886 rows x 3 columns]

# %%
df["title"] = "Sales Associate"

# %%
df3 = df

# %%
df3
# Out:
#            job_id  company_id            title  \
# 0        85008768         NaN  Sales Associate
# 1       133114754  77766802.0  Sales Associate
# 2       133196985   1089558.0  Sales Associate
# 3       381055942  96654609.0  Sales Associate
# 4       529257371   1244539.0  Sales Associate
# ...           ...         ...              ...
# 15881  3701373516  74718032.0  Sales Associate
# 15882  3701373522     38897.0  Sales Associate
# 15883  3701373523     38897.0  Sales Associate
# 15884  3701373524      2623.0  Sales Associate
# 15885  3701373527     84659.0  Sales Associate
#
#                                              description  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# ...

# %%
df3.ndim
# Out:
# 2

# %%
df3.size
# Out:
# 428922

# %%
df3.shape
# Out:
# (15886, 27)

# %%
df3.isnull()
# Out:
#        job_id  company_id  title  description  max_salary  med_salary  \
# 0       False        True  False        False       False        True
# 1       False       False  False        False        True        True
# 2       False       False  False        False        True        True
# 3       False       False  False        False        True        True
# 4       False       False  False        False        True        True
# ...       ...         ...    ...          ...         ...         ...
# 15881   False       False  False        False        True        True
# 15882   False       False  False        False        True        True
# 15883   False       False  False        False        True        True
# 15884   False       False  False        False       False        True
# 15885   False       False  False        False        True        True
#
#        min_salary  pay_period  formatted_work_type  location  ...  expiry  \
# ...

# %%
df3.isnull().sum()
# Out:
# job_id                            0
# company_id                      366
# title                             0
# description                       1
# max_salary                    10365
# med_salary                    14905
# min_salary                    10365
# pay_period                     9384
# formatted_work_type               0
# location                          0
# applies                        7186
# original_listed_time              0
# remote_allowed                13546
# views                          2763
# job_posting_url                   0
# application_url                6091
# application_type                  0
# expiry                            0
# closed_time                   14958
# formatted_experience_level     4902
# skills_desc                   15742
# listed_time                       0
# posting_domain                 6842
# sponsored                         0
# work_type                         0
# currency                       9384
# ...

# %%
df3.to_markdown
# Out:
# <bound method DataFrame.to_markdown of            job_id  company_id            title  \
# 0        85008768         NaN  Sales Associate
# 1       133114754  77766802.0  Sales Associate
# 2       133196985   1089558.0  Sales Associate
# 3       381055942  96654609.0  Sales Associate
# 4       529257371   1244539.0  Sales Associate
# ...           ...         ...              ...
# 15881  3701373516  74718032.0  Sales Associate
# 15882  3701373522     38897.0  Sales Associate
# 15883  3701373523     38897.0  Sales Associate
# 15884  3701373524      2623.0  Sales Associate
# 15885  3701373527     84659.0  Sales Associate
#
#                                              description  max_salary  \
# 0      While many industries were hurt by the last fe...     52000.0
# 1      Are you a dynamic and creative marketing profe...         NaN
# 2      Join Us as a Model Risk Auditor – Showcase You...         NaN
# 3      Business ManagerFirst Baptist Church ForneyFor...         NaN
# ...

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [job_id, company_id, title, description, max_salary, med_salary, min_salary, pay_period, formatted_work_type, location, applies, original_listed_time, remote_allowed, views, job_posting_url, application_url, application_type, expiry, closed_time, formatted_experience_level, skills_desc, listed_time, posting_domain, sponsored, work_type, currency, compensation_type]
# Index: []
#
# [0 rows x 27 columns]
