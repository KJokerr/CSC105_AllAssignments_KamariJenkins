# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/healthcare_data.csv")

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Patient_ID'}>,
#         <Axes: title={'center': 'Age'}>],
#        [<Axes: title={'center': 'Treatment_Cost'}>, <Axes: >]],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      50 non-null     int64
#  1   Patient_Name    50 non-null     object
#  2   Age             50 non-null     int64
#  3   Gender          50 non-null     object
#  4   Blood_Type      50 non-null     object
#  5   Diagnosis       50 non-null     object
#  6   Treatment_Cost  34 non-null     float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 2.9+ KB

# %%
df[df['Gender'] == 'Male']
# Out:
#     Patient_ID          Patient_Name  Age Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45   Male         A+   Hypertension
# 2         1003        Robert Johnson   35   Male         O+         Cancer
# 4         1005         Michael Brown   55   Male        AB+         Asthma
# 6         1007           James Davis   48   Male         O-       Diabetes
# 8         1009          David Wilson   72   Male         A+  Heart Disease
# 10        1011           William Lee   33   Male        AB+   Hypertension
# 12        1013        Richard Taylor   55   Male         O+       Diabetes
# 14        1015         Charles Jones   44   Male        AB-  Heart Disease
# 16        1017        Robert Jackson   29   Male         O-   Hypertension
# 18        1019      Michael Williams   67   Male        AB+  Heart Disease
# 20        1021           John Wilson   38   Male         O+   Hypertension
# ...

# %%
df[df['Diagnosis'] == 'Cancer']
# Out:
#     Patient_ID      Patient_Name  Age  Gender Blood_Type Diagnosis  \
# 2         1003    Robert Johnson   35    Male         O+    Cancer
# 7         1008      Karen Harris   65  Female        AB-    Cancer
# 11        1012        Mary Brown   70  Female         B-    Cancer
# 15        1016      Linda Wilson   62  Female         A+    Cancer
# 22        1023     Daniel Harris   58    Male         A+    Cancer
# 27        1028      Susan Taylor   53  Female         O+    Cancer
# 32        1033    William Harris   30    Male        AB+    Cancer
# 37        1038     Laura Johnson   43  Female        AB+    Cancer
# 42        1043     Matthew Davis   55    Male         O+    Cancer
# 47        1048  Patricia Jackson   39  Female         A+    Cancer
#
#     Treatment_Cost
# 2           5500.0
# 7              NaN
# 11             NaN
# 15          5900.0
# 22          6400.0
# 27          6100.5
# 32             NaN
# 37          6700.0
# 42             NaN
# 47          6700.5

# %%
df[df['Diagnosis'] == 'Cancer'].shape
# Out:
# (10, 7)

# %%
df[df['Age'] > 60]['Treatment_Cost'].mean()
# Out:
# 2553.785714285714

# %%
df.groupby('Blood_Type')['Treatment_Cost'].mean()
# Out:
# Blood_Type
# A+     3594.500000
# A-     1470.300000
# AB+    2232.687500
# AB-    1923.833333
# B+      860.250000
# B-      860.750000
# O+     2870.125000
# O-     1935.250000
# Name: Treatment_Cost, dtype: float64

# %%
## A+ has the highest average treatment cost

# %%
df.groupby(['Gender', 'Diagnosis')['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'Diagnosis'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.groupby('Gender', 'Diagnosis')['Age'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8400, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8398 if level is None and by is None:
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8400 axis = self._get_axis_number(axis)
#    8402 return DataFrameGroupBy(
#    8403     obj=self,
# ...
